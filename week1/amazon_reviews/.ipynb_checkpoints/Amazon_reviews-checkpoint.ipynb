# %%
import os

# %%
import pandas as pd
df=pd.read_json('Automotive_5.json', lines=True)
df.reviewText=df.reviewText.str.lower()
df.reviewText=df.reviewText.str.replace('[^\w\s]','')
# Out:
#              asin   helpful  overall  \
# 0      B00002243X    [4, 4]        5
# 1      B00002243X    [1, 1]        4
# 2      B00002243X    [0, 0]        5
# 3      B00002243X  [19, 19]        5
# 4      B00002243X    [0, 0]        5
# 5      B00002243X    [1, 1]        5
# 6      B00002243X    [1, 1]        5
# 7      B00002243X    [0, 0]        5
# 8      B00002243X    [0, 0]        4
# 9      B00002243X    [0, 0]        5
# 10     B00002243Z    [0, 0]        4
# 11     B00002243Z  [19, 21]        5
# 12     B00002243Z    [0, 0]        5
# 13     B00002243Z  [20, 21]        4
# 14     B00002243Z    [1, 1]        4
# 15     B00002243Z    [1, 3]        4
# 16     B00008BKX5    [0, 0]        3
# 17     B00008BKX5    [3, 4]        4
# 18     B00008BKX5  [51, 51]        5
# 19     B00008BKX5    [0, 0]        5
# 20     B00008BKX5    [0, 0]        5
# 21     B00008BKX5    [0, 0]        4
# 22     B00008BKX5    [1, 1]        5
# 23     B00008RW9U    [1, 2]        5
# ...

# %%
df_stopwords=pd.read_csv("stop-word-list.csv")
#df['reviewText'] = df['reviewText'].apply(lambda x: [item for item in str.split(str(x)) if item not in df_stopwords.columns])
#df['reviewText']= df['reviewText'].str.split()
#df["reviewText"] = df["reviewText"].apply(lambda x : ' '.join([item for item in str.split(str(x)) if item not in stop]))

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")
